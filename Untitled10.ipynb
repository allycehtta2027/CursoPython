# %% [markdown]
# <a href="https://colab.research.google.com/github/allycehtta2027/CursoPython/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# if ear < ear_limiar:
# if ear < ear_limiar:
# Executa a função se a condição for verdadeira
#
# ear: É o valor que você está comparando.
# ear_limiar: O valor limite com o qual você está comparando ear.
# funcao(): A função que será chamada quando a condição for verdadeira. Você pode substituir funcao() pelo nome da função que deseja executar.
#
# t_inicial = time.time()
#  registra o horário atual em segundos
#
#  t_inicial
#  usado para calcular a duração de um processo ou evento.
#
#  if dominio == 0:
#  condicional que verifica se a variável dominio é igual a 0
#
#  dormindo = 1
# condição anterior for verdadeira (ou seja, se dominio for igual a 0), a variável dormindo é definida como 1
#
# if dormindo == 1 and ear >= ear_limiar:
# verifica se dormindo é igual a 1 ou seja, o sistema está em modo dormindo.
#
# dormindo = 0
# condição anterior for verdadeira, o sistema acorda ou muda de estado, alterando a variável dormindo para 0.
#
# t_final = time.time()
# o código novamente usa time.time() para registrar o momento atual, armazenando-o na variável t_final.
#
# tempo = t_final - t_inicial if dormindo == 1 else 0.0
# calcula o tempo decorrido desde t_inicial até t_final, mas apenas se dormindo ainda for 1 indicando que o sistema não foi acordado
