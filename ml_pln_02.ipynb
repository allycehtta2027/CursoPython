# %% [markdown]
# <a href="https://colab.research.google.com/github/allycehtta2027/CursoPython/blob/main/ml_pln_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Problema
# Analisar sentimentos em resenha de filmes, o destaque terá 50.000 filmes para ser analisados, O dataset possui uma coluna que é i sentimemetro (pos - positivo e neg - negativo). No final, devemos treinar um modelo de regressão logistica, mais antes entender e transformar o texto em espaço

# %% [markdown]
# # DATA KAGGLE

# %%
! pip install pandas

# %%
import pandas as pd

# Carrega o arquivo CSV
df_resenhas = pd.read_csv('datasets/imdb-reviews-pt-br.csv')

# %% [markdown]
# # Analise do Dataset:
#
# - Os indices do Dtaframe antecede a coluna id.
# - text_en:é uma coluna que contem um texto inglês
# - text_pt:é a mesma coluna em inglês traduzida para português.
# - sentiment:mostra o sentimento do texto sendo neg (negativos) e pos(positivos)
#
# # Analise de variaveis:
# - **text_en**: qualitativa nominal
# - **text_pt**: qualitativa nominal
# - **sentiment**: qualitativa nominal

# %%
df_resenhas.tail()
# Out:
#    coluna1 coluna2
# 0        1       A
# 1        2       B
# 2        3       C

# %%
df_resenhas.tail()
df_resenhas.tail(10)  # Retorna as últimas 10 linhas
# Out:
#    coluna1 coluna2
# 0        1       A
# 1        2       B
# 2        3       C

# %%
# Exemplo de criação de um DataFrame
import pandas as pd

data = {'coluna1': [1, 2, 3], 'coluna2': ['A', 'B', 'C']}
df_resenhas = pd.DataFrame(data)

# Agora o método tail() vai funcionar
df_resenhas.tail()
# Out:
#    coluna1 coluna2
# 0        1       A
# 1        2       B
# 2        3       C

# %%
if df_resenhas.empty:
    print("O DataFrame está vazio")
else:
    print(df_resenhas.tail())
# Out:
#    coluna1 coluna2
# 0        1       A
# 1        2       B
# 2        3       C

# %% [markdown]
# # Machine Learning
#
# - scikit-lean
# - machine learning in python
# - documentação:https://scikit-learn.org/stable/
# - Ferramentas simples e eficientes para analise preditiva de texto
# - Acessivel a todos e reutilizavel em varios contextos
# - construindo um NumPy. SciPy e matplotilib
# - codigo aberto, comercialmente utilizável - licença BSD
# - modelo de redes neurais, visão computacional

# %% [markdown]
# # Machine Learning
#
# Inteligência artificial é um conceito geral, são maquinas que imitam os seres vivos.
# A Inteligência Artificial é dividida em duas grandes categorias.
# - machine learning: modelos preditivos
# - Deep learning: modelo de redes neurais, visão computacional (CNN)

# %% [markdown]
# # Qual o tipo de machine lerning
# ![machine-learning-types.png](data:image/png;base64,...)

# %% [markdown]
# Variáveis: Em termos simples, uma variável dependente é aquela que está sujeita a mudanças ou variações em resposta a outra variável, chamada de variável independente. Por outro lado, as variáveis independentes são aquelas que representam os fatores ou condições que se acredita influenciarem a variável dependente.

# %% [markdown]
# # Ok escolhemos o texto.

# %% [markdown]
# # Qual Algoritmo escolher

# %% [markdown]
# # TREINO E TESTE

# %% [markdown]
# Separar ou Segregar
#
# 70 - treinar
# 30 - avaliar(esconde)
#
# - Overfitting e Uderfitting

# %%
# importação
from sklearn.model_selection import train_test_split

# definir variáveis de treino e teste
# random_state: passe int para embaralhamento
treino, teste, classe_treino, classe_teste = train_test_split(
    df_resenhas.text_pt, df_resenhas.sentiment, random_state=42
)

# %%
# treino: possui os dados do treino(70%)
# teste: possui os dados de teste (30%)
# classe_treino:rotulos (label) de treino
# classe

# %%
# verificar treino
treino

# %%
# df_resenhas.info()

# %%
# mostrando os rotulos (label) de treino
classe_treino

# %% [markdown]
# Relembrando
# - variavel dependente: nosso alvo(observada no experimento)
# - variavel indenpendente: influenciam o resultado
#
# Independente: Temperatura (°C)
# dependente: taxa de crescimento
#
# Exercícios: Realize uma pesquisa;
#
# - Qual a diferença entre a regressão linear e logistica?
# o que são bag of words
# - o que são matriz esparsa
# - principio de pareto ( teoria e graficos)
