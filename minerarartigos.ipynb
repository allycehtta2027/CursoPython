# %% [markdown]
# <a href="https://colab.research.google.com/github/allycehtta2027/CursoPython/blob/main/minerarartigos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # O que é um artigo?

# %% [markdown]
# # Ambientação (mineração de texto em artigos da internet)

# %% [markdown]
# 1.   Instalação
# 2.   Importação
# 3.   Objeto Goose
# 4.   URL

# %%
! pip install goose3
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 21.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.4/113.4 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 9.0 MB/s eta 0:00:00
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993221 sha256=844ea830e16874f1ba4b147d9f5bdacd20954782a4a6b932bcdcfe041cbcc11f
#   Stored in directory: /root/.cache/pip/wheels/95/03/7d/59ea870c70ce4e5a370638b5462a7711ab78fba2f655d05106
# Successfully built langdetect
# ...

# %%
from goose3 import Goose

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# criar um objeto
# objeto = Construtor()

# %%
class Usuario():
  # metodo construtor
  def __init__(self, nome, nick_name, senha, email)
      self.nome = nome
      self.nick_name = nick_name
      self.senha = senha
      self.email = email

# %%
usuario1 = Usuario()
# Usuario - classe Usuario( ) - construtor

# %%
g = Goose

# %%
url = "https://medium.com/pipeline-a-data-engineering-resource/3-data-science-projects-that-got-me-12-interviews-and-1-that-got-me-in-trouble-f376682b4e21"

# %% [markdown]
# # Fase de Extração
#
# 1.   extract(url)
# 2.   utilizar propriedades (title,texto,data,meta-tags html)
# 3.   web scraping
# 4.   direitos autorais

# %% [markdown]
# # **Desafio** (valendo certificado)
#
#
#
# 1.   Realizar a tokenização de palavras (do arquivo)
# 2.   Realizar a destribuição de frequências da palavra (liberado geral o uso de novos stopwords) - FreqDist e Gráfico de linha.
# 3.   Criar o WorldCloud.
# 4.    Apresentar e receber o certificado.

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('punkt')
nltk.download('stopwords')

# Hino do Flamengo
hino_flamengo = """
Uma vez Flamengo, sempre Flamengo
Flamengo sempre eu hei de ser
É o meu maior prazer vê-lo brilhar
Seja na terra, seja no mar
Vencer, vencer, vencer

Uma vez Flamengo, Flamengo até morrer
Na regata, ele me mata
Me maltrata, me arrebata
Que emoção no coração

Consagrado no gramado
Sempre amado, o mais cotado
Nos Fla-Flus é o "ai, Jesus"
Eu teria um desgosto profundo
Se faltasse o Flamengo no mundo

Ele vibra, ele é fibra
Muita libra já pesou
Flamengo até morrer, eu sou
"""

tokens = word_tokenize(hino_flamengo.lower())

print(tokens_filtrados)
# Out:
# ['vez', 'flamengo', 'sempre', 'flamengo', 'flamengo', 'sempre', 'maior', 'prazer', 'brilhar', 'terra', 'mar', 'vencer', 'vencer', 'vencer', 'vez', 'flamengo', 'flamengo', 'morrer', 'regata', 'mata', 'maltrata', 'arrebata', 'emoção', 'coração', 'consagrado', 'gramado', 'sempre', 'amado', 'cotado', 'ai', 'jesus', 'desgosto', 'profundo', 'faltasse', 'flamengo', 'mundo', 'vibra', 'fibra', 'muita', 'libra', 'pesou', 'flamengo', 'morrer']
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tokens = word_tokenize(hino_flamengo.lower())

tokens_limpos = [palavra for palavra in tokens if palavra.isalnum()]

freq_dist = FreqDist(tokens_limpos)

print(freq_dist.most_common(10))
# Out:
# [('flamengo', 7), ('o', 4), ('no', 4), ('sempre', 3), ('eu', 3), ('é', 3), ('vencer', 3), ('ele', 3), ('me', 3), ('uma', 2)]

# %%
tokens = word_tokenize(hino_flamengo.lower())

words = list(freq_dist.keys())
frequencies = list(freq_dist.values())

plt.figure(figsize=(10, 6))
plt.plot(words, frequencies, marker='o', linestyle='-', color='b')
plt.xlabel('Palavras')
plt.ylabel('Frequência')
plt.title('Distribuição de Frequência das Palavras no Hino do Flamengo')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
tokens = word_tokenize(hino_flamengo.lower())

tokens_limpos = [palavra for palavra in tokens if palavra.isalnum()]

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(texto)


plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Nuvem de Palavras do Hino do Flamengo')
plt.show()
